# %% [markdown]
# # ML Workshop 1: General ML
# # Data Analysis

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline

from collections import defaultdict, OrderedDict, Counter
import copy
import numpy as np
import pandas as pd
from pprint import pprint
import matplotlib.pyplot as plt
from datetime import date, datetime
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Load and print some data

# %%
df = pd.read_csv("/data/cardataset.zip")
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# 5          BMW    1 Series  2012     premium unleaded (required)      230.0
# 6          BMW    1 Series  2012     premium unleaded (required)      300.0
# 7          BMW    1 Series  2012     premium unleaded (required)      300.0
# 8          BMW    1 Series  2012     premium unleaded (required)      230.0
# 9          BMW    1 Series  2013     premium unleaded (required)      230.0
# 10         BMW    1 Series  2013     premium unleaded (required)      300.0
# 11         BMW    1 Series  2013     premium unleaded (required)      230.0
# 12         BMW    1 Series  2013     premium unleaded (required)      300.0
# 13         BMW    1 Series  2013     premium unleaded (required)      230.0
# 14         BMW    1 Series  2013     premium unleaded (required)      230.0
# 15         BMW    1 Series  2013     premium unleaded (required)      320.0
# 16         BMW    1 Series  2013     premium unleaded (required)      320.0
# 17        Audi         100  1992                regular unleaded      172.0
# 18        Audi         100  1992                regular unleaded      172.0
# 19        Audi         100  1992                regular unleaded      172.0
# 20        Audi         100  1992                regular unleaded      172.0
# 21        Audi         100  1992                regular unleaded      172.0
# 22        Audi         100  1993                regular unleaded      172.0
# 23        Audi         100  1993                regular unleaded      172.0
# 24        Audi         100  1993                regular unleaded      172.0
# 25        Audi         100  1993                regular unleaded      172.0
# 26        Audi         100  1993                regular unleaded      172.0
# 27        Audi         100  1994                regular unleaded      172.0
# 28        Audi         100  1994                regular unleaded      172.0
# 29        Audi         100  1994                regular unleaded      172.0
# ...        ...         ...   ...                             ...        ...
# 11884      BMW          Z3  2001     premium unleaded (required)      225.0
# 11885      BMW          Z3  2001     premium unleaded (required)      184.0
# 11886      BMW          Z3  2001     premium unleaded (required)      225.0
# 11887      BMW          Z3  2002     premium unleaded (required)      225.0
# 11888      BMW          Z3  2002     premium unleaded (required)      184.0
# 11889      BMW          Z3  2002     premium unleaded (required)      225.0
# 11890      BMW        Z4 M  2007     premium unleaded (required)      330.0
# 11891      BMW        Z4 M  2007     premium unleaded (required)      330.0
# 11892      BMW        Z4 M  2008     premium unleaded (required)      330.0
# 11893      BMW        Z4 M  2008     premium unleaded (required)      330.0
# 11894      BMW          Z4  2014     premium unleaded (required)      240.0
# 11895      BMW          Z4  2014     premium unleaded (required)      300.0
# 11896      BMW          Z4  2014     premium unleaded (required)      335.0
# 11897      BMW          Z4  2015     premium unleaded (required)      240.0
# 11898      BMW          Z4  2015     premium unleaded (required)      300.0
# 11899      BMW          Z4  2015     premium unleaded (required)      335.0
# 11900      BMW          Z4  2016     premium unleaded (required)      300.0
# 11901      BMW          Z4  2016     premium unleaded (required)      240.0
# 11902      BMW          Z4  2016     premium unleaded (required)      335.0
# 11903      BMW          Z8  2001     premium unleaded (required)      394.0
# 11904      BMW          Z8  2002     premium unleaded (required)      394.0
# 11905      BMW          Z8  2003     premium unleaded (required)      394.0
# 11906    Acura         ZDX  2011     premium unleaded (required)      300.0
# 11907    Acura         ZDX  2011     premium unleaded (required)      300.0
# 11908    Acura         ZDX  2011     premium unleaded (required)      300.0
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 0                   6.0            MANUAL   rear wheel drive              2.0
# 1                   6.0            MANUAL   rear wheel drive              2.0
# 2                   6.0            MANUAL   rear wheel drive              2.0
# 3                   6.0            MANUAL   rear wheel drive              2.0
# 4                   6.0            MANUAL   rear wheel drive              2.0
# 5                   6.0            MANUAL   rear wheel drive              2.0
# 6                   6.0            MANUAL   rear wheel drive              2.0
# 7                   6.0            MANUAL   rear wheel drive              2.0
# 8                   6.0            MANUAL   rear wheel drive              2.0
# 9                   6.0            MANUAL   rear wheel drive              2.0
# 10                  6.0            MANUAL   rear wheel drive              2.0
# 11                  6.0            MANUAL   rear wheel drive              2.0
# 12                  6.0            MANUAL   rear wheel drive              2.0
# 13                  6.0            MANUAL   rear wheel drive              2.0
# 14                  6.0            MANUAL   rear wheel drive              2.0
# 15                  6.0            MANUAL   rear wheel drive              2.0
# 16                  6.0            MANUAL   rear wheel drive              2.0
# 17                  6.0            MANUAL  front wheel drive              4.0
# 18                  6.0            MANUAL  front wheel drive              4.0
# 19                  6.0         AUTOMATIC    all wheel drive              4.0
# 20                  6.0            MANUAL  front wheel drive              4.0
# 21                  6.0            MANUAL    all wheel drive              4.0
# 22                  6.0            MANUAL  front wheel drive              4.0
# 23                  6.0         AUTOMATIC    all wheel drive              4.0
# 24                  6.0            MANUAL  front wheel drive              4.0
# 25                  6.0            MANUAL  front wheel drive              4.0
# 26                  6.0            MANUAL    all wheel drive              4.0
# 27                  6.0         AUTOMATIC  front wheel drive              4.0
# 28                  6.0            MANUAL    all wheel drive              4.0
# 29                  6.0            MANUAL  front wheel drive              4.0
# ...                 ...               ...                ...              ...
# 11884               6.0            MANUAL   rear wheel drive              2.0
# 11885               6.0            MANUAL   rear wheel drive              2.0
# 11886               6.0            MANUAL   rear wheel drive              2.0
# 11887               6.0            MANUAL   rear wheel drive              2.0
# 11888               6.0            MANUAL   rear wheel drive              2.0
# 11889               6.0            MANUAL   rear wheel drive              2.0
# 11890               6.0            MANUAL   rear wheel drive              2.0
# 11891               6.0            MANUAL   rear wheel drive              2.0
# 11892               6.0            MANUAL   rear wheel drive              2.0
# 11893               6.0            MANUAL   rear wheel drive              2.0
# 11894               4.0            MANUAL   rear wheel drive              2.0
# 11895               6.0            MANUAL   rear wheel drive              2.0
# 11896               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11897               4.0            MANUAL   rear wheel drive              2.0
# 11898               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11899               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11900               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11901               4.0            MANUAL   rear wheel drive              2.0
# 11902               6.0  AUTOMATED_MANUAL   rear wheel drive              2.0
# 11903               8.0            MANUAL   rear wheel drive              2.0
# 11904               8.0            MANUAL   rear wheel drive              2.0
# 11905               8.0            MANUAL   rear wheel drive              2.0
# 11906               6.0         AUTOMATIC    all wheel drive              4.0
# 11907               6.0         AUTOMATIC    all wheel drive              4.0
# 11908               6.0         AUTOMATIC    all wheel drive              4.0
# 11909               6.0         AUTOMATIC    all wheel drive              4.0
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                              Market Category Vehicle Size  Vehicle Style  \
# 0      Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 1                         Luxury,Performance      Compact    Convertible
# 2                    Luxury,High-Performance      Compact          Coupe
# 3                         Luxury,Performance      Compact          Coupe
# 4                                     Luxury      Compact    Convertible
# 5                         Luxury,Performance      Compact          Coupe
# 6                         Luxury,Performance      Compact    Convertible
# 7                    Luxury,High-Performance      Compact          Coupe
# 8                                     Luxury      Compact    Convertible
# 9                                     Luxury      Compact    Convertible
# 10                   Luxury,High-Performance      Compact          Coupe
# 11                        Luxury,Performance      Compact          Coupe
# 12                        Luxury,Performance      Compact    Convertible
# 13                                    Luxury      Compact    Convertible
# 14                        Luxury,Performance      Compact          Coupe
# 15                   Luxury,High-Performance      Compact    Convertible
# 16                   Luxury,High-Performance      Compact          Coupe
# 17                                    Luxury      Midsize          Sedan
# 18                                    Luxury      Midsize          Sedan
# 19                                    Luxury      Midsize          Wagon
# 20                                    Luxury      Midsize          Sedan
# 21                                    Luxury      Midsize          Sedan
# 22                                    Luxury      Midsize          Sedan
# 23                                    Luxury      Midsize          Wagon
# 24                                    Luxury      Midsize          Sedan
# 25                                    Luxury      Midsize          Sedan
# 26                                    Luxury      Midsize          Sedan
# 27                                    Luxury      Midsize          Wagon
# 28                                    Luxury      Midsize          Sedan
# 29                                    Luxury      Midsize          Sedan
# ...                                      ...          ...            ...
# 11884                     Luxury,Performance      Compact    Convertible
# 11885                     Luxury,Performance      Compact    Convertible
# 11886           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11887                     Luxury,Performance      Compact    Convertible
# 11888                     Luxury,Performance      Compact    Convertible
# 11889           Hatchback,Luxury,Performance      Compact  2dr Hatchback
# 11890  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11891  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11892  Factory Tuner,Luxury,High-Performance      Compact          Coupe
# 11893  Factory Tuner,Luxury,High-Performance      Compact    Convertible
# 11894                     Luxury,Performance      Compact    Convertible
# 11895                Luxury,High-Performance      Compact    Convertible
# 11896                Luxury,High-Performance      Compact    Convertible
# 11897                     Luxury,Performance      Compact    Convertible
# 11898                Luxury,High-Performance      Compact    Convertible
# 11899                Luxury,High-Performance      Compact    Convertible
# 11900                Luxury,High-Performance      Compact    Convertible
# 11901                     Luxury,Performance      Compact    Convertible
# 11902                Luxury,High-Performance      Compact    Convertible
# 11903         Exotic,Luxury,High-Performance      Compact    Convertible
# 11904         Exotic,Luxury,High-Performance      Compact    Convertible
# 11905         Exotic,Luxury,High-Performance      Compact    Convertible
# 11906             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11907             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11908             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11909             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11910             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11911             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11912             Crossover,Hatchback,Luxury      Midsize  4dr Hatchback
# 11913                                 Luxury      Midsize          Sedan
#
#        highway MPG  city mpg  Popularity    MSRP
# 0               26        19        3916   46135
# 1               28        19        3916   40650
# 2               28        20        3916   36350
# 3               28        18        3916   29450
# 4               28        18        3916   34500
# 5               28        18        3916   31200
# 6               26        17        3916   44100
# 7               28        20        3916   39300
# 8               28        18        3916   36900
# 9               27        18        3916   37200
# 10              28        20        3916   39600
# 11              28        19        3916   31500
# 12              28        19        3916   44400
# 13              28        19        3916   37200
# 14              28        19        3916   31500
# 15              25        18        3916   48250
# 16              28        20        3916   43550
# 17              24        17        3105    2000
# 18              24        17        3105    2000
# 19              20        16        3105    2000
# 20              24        17        3105    2000
# 21              21        16        3105    2000
# 22              24        17        3105    2000
# 23              20        16        3105    2000
# 24              24        17        3105    2000
# 25              24        17        3105    2000
# 26              21        16        3105    2000
# 27              21        16        3105    2000
# 28              22        16        3105    2000
# 29              22        17        3105    2000
# ...            ...       ...         ...     ...
# 11884           26        19        3916   37900
# 11885           25        18        3916   31300
# 11886           26        19        3916   37700
# 11887           26        19        3916   37900
# 11888           25        18        3916   31300
# 11889           26        19        3916   37700
# 11890           22        15        3916   50100
# 11891           22        15        3916   52100
# 11892           23        15        3916   50400
# 11893           23        15        3916   52400
# 11894           34        22        3916   48950
# 11895           26        19        3916   56950
# 11896           24        17        3916   65800
# 11897           34        22        3916   48950
# 11898           24        17        3916   56950
# 11899           24        17        3916   65800
# 11900           24        17        3916   57500
# 11901           34        22        3916   49700
# 11902           24        17        3916   66350
# 11903           19        12        3916  128000
# 11904           19        12        3916  130000
# 11905           19        12        3916  131500
# 11906           23        16         204   46020
# 11907           23        16         204   56570
# 11908           23        16         204   50520
# 11909           23        16         204   46120
# 11910           23        16         204   56670
# 11911           23        16         204   50620
# 11912           23        16         204   50920
# 11913           26        17          61   28995
#
# [11914 rows x 16 columns]

# %%
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# # Check data types

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG            int64
# city mpg               int64
# Popularity             int64
# MSRP                   int64
# dtype: object

# %% [markdown]
# All types as expected, sometimes mixing int and float but it doesn't matter so much.

# %%
numerical = [col for col, type_ in df.dtypes.items() if type_ in (np.int64, np.float64)]
categorical = [col for col, type_ in df.dtypes.items() if col not in numerical]

print("numerical", numerical)
print("categorical", categorical)
# Out:
# numerical ['Year', 'Engine HP', 'Engine Cylinders', 'Number of Doors', 'highway MPG', 'city mpg', 'Popularity', 'MSRP']
# categorical ['Make', 'Model', 'Engine Fuel Type', 'Transmission Type', 'Driven_Wheels', 'Market Category', 'Vehicle Size', 'Vehicle Style']

# %%
df.describe()
# Out:
#                Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  11914.000000  11845.00000      11884.000000     11908.000000
# mean    2010.384338    249.38607          5.628829         3.436093
# std        7.579740    109.19187          1.780559         0.881315
# min     1990.000000     55.00000          0.000000         2.000000
# 25%     2007.000000    170.00000          4.000000         2.000000
# 50%     2015.000000    227.00000          6.000000         4.000000
# 75%     2016.000000    300.00000          6.000000         4.000000
# max     2017.000000   1001.00000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11914.000000  11914.000000  11914.000000  1.191400e+04
# mean      26.637485     19.733255   1554.911197  4.059474e+04
# std        8.863001      8.987798   1441.855347  6.010910e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# 25%       22.000000     16.000000    549.000000  2.100000e+04
# 50%       26.000000     18.000000   1385.000000  2.999500e+04
# 75%       30.000000     22.000000   2009.000000  4.223125e+04
# max      354.000000    137.000000   5657.000000  2.065902e+06

# %% [markdown]
# - Missing data at columns "Engine HP", "Engine Cylinders", "Number of Doors"
# - max(Year) = 2017, dataset published on Dec 2016, some data for future
# - std > 0 for all columns => not constant columns
# - min(Engine Cylinders) = 0 => weird

# %% [markdown]
# Don't understand MPG, transform to l/100km

# %%
def mpg_to_l100km(mpg):
    return 235.21 / mpg

min_mpg = min(min(df["city mpg"]), min(df["highway MPG"]))
max_mpg =  min(max(df["city mpg"]), max(df["highway MPG"]))

print("Min {}mpg, {} l/100km".format(min_mpg, mpg_to_l100km(min_mpg)))
print("Max {}mpg, {} l/100km".format(max_mpg, mpg_to_l100km(max_mpg)))
# Out:
# Min 7mpg, 33.60142857142857 l/100km
# Max 137mpg, 1.7168613138686133 l/100km

# %% [markdown]
# 0.66 l/100 km strange but might be OK

# %% [markdown]
# # Histograms

# %%
for col in numerical:
    ax = df[[col]].plot.hist(title=col + " histogram")
    ax.set_xlabel("Value")

# %% [markdown]
# - year, Engine HP, MPG, MSRP - Not very nice distribution => data transformation might help

# %%
MAX_VALUES_TO_PLOT = 20

for col in categorical:
    value_counts = df[col].value_counts(normalize=True)
    if len(value_counts) <= MAX_VALUES_TO_PLOT:
        plt.figure()
        ax = value_counts.plot(kind='bar')
        ax.set_xlabel("Value")
        ax.set_ylabel("Frequency")
        ax.set_title(col + " hisotgram")
    else:
        print("=== {} ===".format(col))
        print(value_counts)
        print()
# Out:
# === Make ===
# Chevrolet        0.094259
# Ford             0.073947
# Volkswagen       0.067903
# Toyota           0.062615
# Dodge            0.052543
# Nissan           0.046836
# GMC              0.043226
# Honda            0.037687
# Mazda            0.035504
# Cadillac         0.033322
# Mercedes-Benz    0.029629
# Suzuki           0.029461
# BMW              0.028034
# Infiniti         0.027699
# Audi             0.027531
# Hyundai          0.025432
# Volvo            0.023586
# Subaru           0.021487
# Acura            0.021152
# Kia              0.019389
# Mitsubishi       0.017878
# Lexus            0.016955
# Buick            0.016451
# Chrysler         0.015696
# Pontiac          0.015612
# Lincoln          0.013765
# Oldsmobile       0.012590
# Land Rover       0.012003
# Porsche          0.011415
# Saab             0.009317
# Aston Martin     0.007806
# Plymouth         0.006883
# Bentley          0.006211
# Ferrari          0.005792
# FIAT             0.005204
# Scion            0.005036
# Maserati         0.004868
# Lamborghini      0.004365
# Rolls-Royce      0.002602
# Lotus            0.002434
# Tesla            0.001511
# HUMMER           0.001427
# Maybach          0.001343
# Alfa Romeo       0.000420
# McLaren          0.000420
# Genesis          0.000252
# Spyker           0.000252
# Bugatti          0.000252
# Name: Make, dtype: float64
#
# === Model ===
# Silverado 1500                      0.013094
# Tundra                              0.011751
# F-150                               0.010576
# Sierra 1500                         0.007554
# Beetle Convertible                  0.007470
# Tacoma                              0.006715
# Frontier                            0.006379
# GTI                                 0.006379
# Beetle                              0.006295
# Accord                              0.006295
# Civic                               0.005708
# Dakota                              0.005456
# Ram Pickup 1500                     0.005204
# Jetta                               0.005120
# Corvette                            0.005036
# 911                                 0.004868
# C/K 1500 Series                     0.004700
# Colorado                            0.004532
# XC60                                0.004532
# 3                                   0.004449
# 370Z                                0.004281
# Sienna                              0.004281
# Golf GTI                            0.004197
# E-Class                             0.004113
# Silverado 1500 Classic              0.004113
# Sierra 1500 Classic                 0.004113
# Transit Wagon                       0.004029
# Canyon                              0.004029
# Pilot                               0.004029
# F-250                               0.004029
#                                       ...
# 650S Spider                         0.000084
# Zephyr                              0.000084
# California T                        0.000084
# RS 6                                0.000084
# Continental GT Speed Convertible    0.000084
# Yukon Denali                        0.000084
# Omni                                0.000084
# Sierra C3                           0.000084
# Enzo                                0.000084
# Alpina                              0.000084
# Continental GT3-R                   0.000084
# Dawn                                0.000084
# 650S Coupe                          0.000084
# 570S                                0.000084
# Diablo                              0.000084
# Estate Wagon                        0.000084
# Cayman S                            0.000084
# Reventon                            0.000084
# Precis                              0.000084
# Pulsar                              0.000084
# Blackwood                           0.000084
# Sixty Special                       0.000084
# GS F                                0.000084
# Syclone                             0.000084
# ML55 AMG                            0.000084
# G3                                  0.000084
# Accord Plug-In Hybrid               0.000084
# MKZ Hybrid                          0.000084
# XC                                  0.000084
# M4 GTS                              0.000084
# Name: Model, Length: 915, dtype: float64
#
# === Market Category ===
# Crossover                                                 0.135830
# Flex Fuel                                                 0.106706
# Luxury                                                    0.104626
# Luxury,Performance                                        0.082354
# Hatchback                                                 0.078439
# Performance                                               0.073544
# Crossover,Luxury                                          0.050171
# Luxury,High-Performance                                   0.040871
# Exotic,High-Performance                                   0.031938
# Hatchback,Performance                                     0.030837
# Factory Tuner,Luxury,High-Performance                     0.026309
# High-Performance                                          0.024351
# Hybrid                                                    0.015051
# Crossover,Luxury,Performance                              0.013828
# Factory Tuner,High-Performance                            0.012971
# Factory Tuner,Performance                                 0.011258
# Flex Fuel,Performance                                     0.010646
# Diesel                                                    0.010279
# Exotic,Luxury,High-Performance                            0.009667
# Crossover,Hatchback                                       0.008811
# Hatchback,Hybrid                                          0.008811
# Crossover,Performance                                     0.008443
# Crossover,Flex Fuel                                       0.007832
# Luxury,Hybrid                                             0.006363
# Exotic,Factory Tuner,Luxury,High-Performance              0.006363
# Diesel,Luxury                                             0.006241
# Hatchback,Luxury                                          0.005629
# Crossover,Hybrid                                          0.005140
# Flex Fuel,Luxury                                          0.004772
# Hatchback,Luxury,Performance                              0.004650
#                                                             ...
# Exotic,Flex Fuel,Factory Tuner,Luxury,High-Performance    0.001591
# Hatchback,Factory Tuner,High-Performance                  0.001591
# Exotic,Luxury                                             0.001468
# Luxury,High-Performance,Hybrid                            0.001468
# Exotic,Flex Fuel,Luxury,High-Performance                  0.001346
# Luxury,Performance,Hybrid                                 0.001346
# Crossover,Flex Fuel,Luxury                                0.001224
# Exotic,Performance                                        0.001224
# Hatchback,Factory Tuner,Luxury,Performance                0.001101
# Crossover,Luxury,High-Performance                         0.001101
# Crossover,Diesel                                          0.000857
# Crossover,Hatchback,Luxury                                0.000857
# Hatchback,Flex Fuel                                       0.000857
# Crossover,Hatchback,Factory Tuner,Performance             0.000734
# Crossover,Flex Fuel,Luxury,Performance                    0.000734
# Crossover,Flex Fuel,Performance                           0.000734
# Crossover,Hatchback,Performance                           0.000734
# Crossover,Factory Tuner,Luxury,Performance                0.000612
# Crossover,Factory Tuner,Performance                       0.000489
# Hatchback,Luxury,Hybrid                                   0.000367
# Exotic,Factory Tuner,Luxury,Performance                   0.000367
# Flex Fuel,Performance,Hybrid                              0.000245
# Crossover,Luxury,Performance,Hybrid                       0.000245
# Factory Tuner,Luxury                                      0.000245
# Flex Fuel,Hybrid                                          0.000245
# Exotic,Luxury,High-Performance,Hybrid                     0.000122
# Performance,Hybrid                                        0.000122
# Flex Fuel,Factory Tuner,Luxury,High-Performance           0.000122
# Crossover,Exotic,Luxury,High-Performance                  0.000122
# Crossover,Exotic,Luxury,Performance                       0.000122
# Name: Market Category, Length: 71, dtype: float64

# %% [markdown]
# - "Market category" - more values, we should split
# - "Engine Fuel type" - diesel => not a lot
# - "Driven_wheels" - all_wheel_drive and four_wheel_drive difference??? Maybe we can join to one category

# %% [markdown]
# # Correlations

# %%
df_corr = df.corr()
df_corr
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# highway MPG          1.000000  0.886829   -0.020991 -0.160043
# city mpg             0.886829  1.000000   -0.003217 -0.157676
# Popularity          -0.020991 -0.003217    1.000000 -0.048476
# MSRP                -0.160043 -0.157676   -0.048476  1.000000

# %% [markdown]
# Last colums tells me the potencial of the signal for prediction

# %% [markdown]
# ### Get the most correlating pairs

# %%
CORR_THRESHOLD = 0.2

most_correlated_pairs = []

for i_col1, (col1, row) in enumerate(df_corr.items()):
    for i_col2, (col2, val) in enumerate(row.items()):
        
        # avoid duplicity and same columns
        if i_col1 <= i_col2:
            continue
            
        if abs(val) > CORR_THRESHOLD:
            most_correlated_pairs.append((col1, col2, val))
            
# Sort
most_correlated_pairs = sorted(most_correlated_pairs, key=lambda x: abs(x[2]), reverse=True)
most_correlated_pairs
# Out:
# [('city mpg', 'highway MPG', 0.8868294962591696),
#  ('Engine Cylinders', 'Engine HP', 0.7799879704685222),
#  ('MSRP', 'Engine HP', 0.6620076606110064),
#  ('highway MPG', 'Engine Cylinders', -0.6216057332861424),
#  ('city mpg', 'Engine Cylinders', -0.6007763119730104),
#  ('MSRP', 'Engine Cylinders', 0.5313124863741728),
#  ('city mpg', 'Engine HP', -0.43937125813556127),
#  ('highway MPG', 'Engine HP', -0.4065625665782776),
#  ('Engine HP', 'Year', 0.35179394240882894),
#  ('Number of Doors', 'Year', 0.2637872829658482),
#  ('highway MPG', 'Year', 0.25823982267572665),
#  ('MSRP', 'Year', 0.2275895141047356)]

# %% [markdown]
# - MPG correlation - not a surprise
# - Engine HP/cylinders - not a surprise
# - MSRP, Engine HP/Cylinders => Engine will probably be the best predictor

# %%
for col1, col2, val in most_correlated_pairs:
    df.plot.scatter(x=col1, y=col2, alpha=0.1)

# %% [markdown]
# - annomaly in Highway MPG => explore and correct/get rid of it
# - most graphs not very linear, data transformation might be good idea
# - over 1.5M too few examples => if it makes sense for the task get rid of it

# %% [markdown]
# ### Plot the correlations with target

# %%
for col1 in numerical
    df.plot.scatter(x=col1, y="MSRP", alpha=0.1)

# %% [markdown]
# # Transformations

# %%
col = "city mpg"
col_trans = col+"_trans"

df.loc[:, col_trans] = 1/df[col]

df[[col]].plot.hist(title="Original")
df[[col_trans]].plot.hist(title="Transformed")

df.plot.scatter(x=col, y="MSRP", alpha=0.1, title="Original")
df.plot.scatter(x=col_trans, y="MSRP", alpha=0.1, title="Transformed")

del df[col_trans]

# %% [markdown]
# # Clean data

# %% [markdown]
# ### Highway MPG

# %%
df[df["highway MPG"] > 300]
# Out:
#       Make Model  Year                Engine Fuel Type  Engine HP  \
# 1119  Audi    A6  2017  premium unleaded (recommended)      252.0
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 1119               4.0  AUTOMATED_MANUAL  front wheel drive              4.0
#
#      Market Category Vehicle Size Vehicle Style  highway MPG  city mpg  \
# 1119          Luxury      Midsize         Sedan          354        24
#
#       Popularity   MSRP
# 1119        3105  51600

# %%
df.loc[1119,"highway MPG"] = 35  # Not using /= 10 due to repetitive script trigger
df.loc[1119, :]
# Out:
# Make                                           Audi
# Model                                            A6
# Year                                           2017
# Engine Fuel Type     premium unleaded (recommended)
# Engine HP                                       252
# Engine Cylinders                                  4
# Transmission Type                  AUTOMATED_MANUAL
# Driven_Wheels                     front wheel drive
# Number of Doors                                   4
# Market Category                              Luxury
# Vehicle Size                                Midsize
# Vehicle Style                                 Sedan
# highway MPG                                      35
# city mpg                                         24
# Popularity                                     3105
# MSRP                                          51600
# Name: 1119, dtype: object

# %% [markdown]
# ### MSRP

# %%
print(df.shape)
df[df["MSRP"] > 1000000]
# Out:
# (11914, 16)
#               Make        Model  Year             Engine Fuel Type  Engine HP  \
# 6350       Maybach    Landaulet  2011  premium unleaded (required)      620.0
# 6351       Maybach    Landaulet  2012  premium unleaded (required)      620.0
# 8486   Lamborghini     Reventon  2008  premium unleaded (required)      650.0
# 11362      Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11363      Bugatti  Veyron 16.4  2008  premium unleaded (required)     1001.0
# 11364      Bugatti  Veyron 16.4  2009  premium unleaded (required)     1001.0
#
#        Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 6350               12.0         AUTOMATIC  rear wheel drive              4.0
# 6351               12.0         AUTOMATIC  rear wheel drive              4.0
# 8486               12.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11362              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11363              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
# 11364              16.0  AUTOMATED_MANUAL   all wheel drive              2.0
#
#                       Market Category Vehicle Size Vehicle Style  highway MPG  \
# 6350   Exotic,Luxury,High-Performance        Large   Convertible           16
# 6351        Exotic,Luxury,Performance        Large   Convertible           16
# 8486          Exotic,High-Performance      Compact         Coupe           14
# 11362         Exotic,High-Performance      Compact         Coupe           14
# 11363         Exotic,High-Performance      Compact         Coupe           14
# 11364         Exotic,High-Performance      Compact         Coupe           14
#
#        city mpg  Popularity     MSRP
# 6350         10          67  1380000
# 6351         10          67  1382750
# 8486          9        1158  1500000
# 11362         8         820  2065902
# 11363         8         820  1500000
# 11364         8         820  1705769

# %%
df = df[df["MSRP"] <= 1000000]
print(df.shape)
df[df["MSRP"] > 1000000]
# Out:
# (11908, 17)
# Empty DataFrame
# Columns: [Make, Model, Year, Engine Fuel Type, Engine HP, Engine Cylinders, Transmission Type, Driven_Wheels, Number of Doors, Market Category, Vehicle Size, Vehicle Style, highway MPG, city mpg, Popularity, MSRP, city mpg_trans]
# Index: []

# %% [markdown]
# # Split to train/dev/test set

# %%
from sklearn.model_selection import train_test_split

def train_dev_test_split(d, sizes):
    train_dev, test = train_test_split(df, test_size=splits[2], random_state=1)
    test_size = splits[1] / sum(splits[:2])  # to get 20% of the total, not 20% of  the 80%
    train, dev = train_test_split(train_dev, test_size=test_size, random_state=1)
    
    return train, dev, test

splits = (0.6, 0.2, 0.2)
datasets = {}
datasets["train"], datasets["dev"], datasets["test"] = train_dev_test_split(df, splits)


for name, dataset in datasets.items():
    print("{} len={}, {}".format(name, len(dataset), len(dataset)/len(df)))
# Out:
# train len=7144, 0.5999328182734296
# dev len=2382, 0.20003359086328518
# test len=2382, 0.20003359086328518

# %%
for name, dataset in datasets.items():
    dataset.to_csv("data/data_clean_{}.csv".format(name))
